# %% [markdown]
# # Fiber Network
#
# The problem provided in this example is a fiber network with fixed-fixed (both displacement and moments) boundary conditions with a prescribed compressive displacement (i.e. nonhomogenous Dirichlet Boundary Condition) on the top boundary. Each fiber is modeled with 2D geometrically exact beams (i.e. Simo-Reissner Beams). For more information on beams [see here](../force_control/beam/README.md).
#
#
#
# <img src="imgs/fiber.png" width="500">

# %%
# %matplotlib inline
from dolfin import *
import numpy as np
import matplotlib.pyplot as plt
from ufl import diag, Jacobian, shape
from arc_length.displacement_control_solver import displacement_control # import displacement control formulation of arc-length solver


parameters["form_compiler"]["cpp_optimize"] = True
parameters["form_compiler"]["quadrature_degree"] = 3
parameters['reorder_dofs_serial'] = False

ffc_options = {"optimize": True, \
               "eliminate_zeros": True, \
               "precompute_basis_const": True, \
               "precompute_ip_const": True}

# %% [markdown]
# ## Import Mesh and define function spaces
# In the case of 2D beams we also define the rotation matrix about the $z$ axis and directional derivative with respect to the beam centerline.

# %%
mesh = Mesh()
with XDMFFile('./examples/displacement_control/voronoi.xdmf') as infile:
    infile.read(mesh)
    

Ue = VectorElement("CG", mesh.ufl_cell(), 2, dim=2) # displacement
Te = FiniteElement("CG", mesh.ufl_cell(), 1) # rotation


V = FunctionSpace(mesh, MixedElement([Ue, Te]))   

v_ = TestFunction(V)
u_, theta_ = split(v_)
dv = TrialFunction(V)
v = Function(V, name="Generalized displacement")
u, theta = split(v)

VR = TensorFunctionSpace(mesh, "DG", 0, shape=(2, 2))

V0 = FunctionSpace(mesh, "DG", 0)



Vu = V.sub(0).collapse()
disp = Function(Vu)

Jac = Jacobian(mesh)
gdim = mesh.geometry().dim()
Jac = as_vector([Jac[i, 0] for i in range(gdim)])
g01 = Jac/sqrt(dot(Jac, Jac))
g02 = as_vector([-g01[1],g01[0]])

r01 = outer(g01,as_vector([1,0]))
r02 = outer(g02, as_vector([0,1]))

R0 = r01+r02

#-----------------------Define Functions for beams-----------------------------------#
def tgrad(u): # directional derivative w.r.t. beam centerline
    return dot(grad(u), g01)

def rotation_matrix(theta): # 2D rotation matrix -- there is no need to do rotation parametrization for 2D beams
    return as_tensor([[cos(theta), -sin(theta)],[sin(theta), cos(theta)]])
Rot = rotation_matrix(theta)

# %% [markdown]
# ## Define Dirichlet Boundary Conditions
#
#
# **Note that for the case of displacement control, the FEniCS expression for the applied displacement mujst have be positive to prevent convergence issues.**
#
# For example:
#
# ```
# apply_disp = Expression("t", t = 0.0, degree = 0)
# ```
# is valid and will not have convergence issues while
# ```
# apply_disp = Expression("-t", t = 0.0, degree = 0)
# ```
# can cause convergence issues.
#
# The direction of applied loading will be determined by the initial load step.

# %%
H = 100.0
w = 100.0

def bottom(x, on_boundary):
    return near(x[1], 0, 1e-6) 
def top(x, on_boundary):
    return near(x[1], H,1e-6) 

def left(x, on_boundary):
    return near(x[0], 0,1e-6)
def right(x, on_boundary):
    return near(x[0], w,1e-6)


BC_bot = DirichletBC(V, Constant((0.0,0.0,0.0)), bottom) # fixed displacement and rotation
BC_top_x = DirichletBC(V.sub(0).sub(0), Constant(0.0), top) # fix displacement
BC_top_rot = DirichletBC(V.sub(1), Constant(0.0), top) # fix rotation

apply_disp = Expression("t", t=0.0, degree = 0) # Create expression to compress the top
BC_top_y = DirichletBC(V.sub(0).sub(1),apply_disp,top) # incrementally compress the top 

bcs = [BC_bot, BC_top_y, BC_top_rot, BC_top_x]

# %% [markdown]
# ## Kinematics and Weak Form

# %%
# Kinematics: This is "total" beam formulation
defo = dot(R0.T,dot(Rot.T, g01 + tgrad(u)) - g01)
curv =  tgrad(theta)

# %%
# Geometrical properties
S = 1.5*3 # cross-sectional area
I = 3*1.5**3/12 # Area moment
G = 0.0412 # Shear Modulus
nu = 0.5
E = 2*G*(1+nu)

kappa = 5*(1+nu)/(6+5*nu) # Shear correction (Timoshenko)



# Stiffness moduli
ES = E*S
GS = G*kappa*S
EI = E*I

# %%
# Constitutive Equations
C_N = diag(as_vector([ES, GS]))

# Applied Load:
F_max = Constant((0.0,0.0))
M_max = Constant(0.0)

elastic_energy = 0.5 * (dot(defo, dot(C_N, defo)) + (EI*curv**2))*dx

F_int = derivative(elastic_energy, v, v_)
F_ext =(-M_max*theta_ + dot(F_max, u_)) * ds
residual = F_int - F_ext
tangent_form = derivative(residual, v, dv)

# %% [markdown]
# ## Solver
# To use our solver we first have to define the type of solver (i.e. displacement control or force control) and solver parameters before using the solver. Note that the correct type of solver has to first be imported (see first cell).
# ### Solver parameters
# Here the parameters for both types of solvers:
#
# >* `psi` : the scalar arc-length parameter. When psi = 1, the method becomes the spherical arc-length method and when psi = 0 the method becomes the cylindrical arc-length method
# >* `abs_tol` *(optional)* : absolute residual tolerance for the linear solver (default value: 1e-10)
# >* `rel_tol` *(optional)* :  relative residual tolerance for solver; the relative residual is defined as the ration between the current residual and initial residual (default value: DOLFIN_EPS)
# >* `lmbda0` : the initial load parameter
# >* `max_iter` : maximum number of iterations for the linear solver
# >* `solver` *(optional)*: type of linear solver for the FEniCS linear solve function -- default FEniCS linear solver is used if no argument is used.
#
# Aside from these solver parameters, the arguments need to solve the FEA problem must also be passed into the solver:
# >* `u` : the solution function
# >* `F_int` : First variation of strain energy (internal nodal forces)
# >* `F_ext` : Externally applied load (external applied force)
# >* `J` : The Jacobian of the residual with respect to the deformation (tangential stiffness matrix)
# >* `displacement_factor` : The incremental displacement factor
#
# The solver can be called by:
#
# `solver = force_control(psi,abs_tol,rel_tol,lmbda0,max_iter,u,F_int,F_ext,bcs,J,displacement_factor,solver)`
#
# ### Using the solver
# 1. Initialize the solver by calling solver.initialize()
# 2. Iteratively call solver.solve() until desired stopping condition

# %%
# Solver Parameters
psi = 1.0
abs_tol = 1.0e-6
lmbda0 = -0.5 # negative for compression
max_iter = 20
solver = 'mumps'

# Set up arc-length solver
solver = displacement_control(psi=psi, lmbda0=lmbda0, max_iter=max_iter, u=v,
                       F_int=F_int, F_ext=F_ext, bcs=bcs, J=tangent_form, displacement_factor = apply_disp, solver = solver)

# %%
disp = [v.vector()[:]]
lmbda = [0]
# Function space to compute reaction force at each iteration
v_reac = Function(V)
bcRy = DirichletBC(V.sub(0).sub(1), Constant(1.0), bottom) # take reaction force from the bottom
f_reac = [0.0]
for ii in range(0,55):
    solver.solve()
    if solver.converged:
        # Store whole displacement field
        disp.append(v.vector()[:])
        # Store displacement factor
        lmbda.append(apply_disp.t)
        # Compute and store reaction force
        bcRy.apply(v_reac.vector())
        f_reac.append(assemble(action(residual,v_reac)))
# Out:
# Initializing solver parameters...
# Starting initial Displacement Control Control with Newton Method:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Iteration 0: |
# Absolute Residual: 2.7574e+00| Relative Residual: 1.0000e+00
# Iteration 1: |
# Absolute Residual: 1.0849e-01| Relative Residual: 3.9345e-02
# Iteration 2: |
# Absolute Residual: 9.9644e-03| Relative Residual: 3.6137e-03
# Iteration 3: |
# Absolute Residual: 2.8527e-05| Relative Residual: 1.0345e-05
# Iteration 4: |
# Absolute Residual: 8.8648e-09| Relative Residual: 3.2149e-09
# Iteration 5: |
# Absolute Residual: 1.3723e-14| Relative Residual: 4.9769e-15
#
# Arc-Length Step 1 :
# Iteration: 0
# |Total Norm: 1.3723e-14 |Residual: 1.3723e-14 |A: 0.0000e+00| Relative Norm : 1.0000e+00
# Calling FFC just-in-time (JIT) compiler, this may take some time.
#
# Arc-Length Step 2 :
# Iteration: 0
# |Total Norm: 2.9462e-03 |Residual: 1.0129e-03 |A: -2.7666e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.3046e-02 |Residual: 2.8952e-07 |A: 1.3046e-02| Relative Norm : 4.4282e+00
# Iteration: 2
# |Total Norm: 1.2453e-07 |Residual: 1.9003e-12 |A: 1.2453e-07| Relative Norm : 4.2267e-05
# Iteration: 3
# |Total Norm: 4.5531e-13 |Residual: 2.2709e-14 |A: 4.5475e-13| Relative Norm : 1.5454e-10
#
# Arc-Length Step 3 :
# Iteration: 0
# |Total Norm: 2.9334e-03 |Residual: 1.0247e-03 |A: -2.7486e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.4280e-02 |Residual: 2.9981e-07 |A: 1.4280e-02| Relative Norm : 4.8682e+00
# Iteration: 2
# |Total Norm: 1.4257e-07 |Residual: 2.0650e-12 |A: 1.4257e-07| Relative Norm : 4.8601e-05
# Iteration: 3
# |Total Norm: 3.4371e-13 |Residual: 4.2616e-14 |A: 3.4106e-13| Relative Norm : 1.1717e-10
#
# Arc-Length Step 4 :
# Iteration: 0
# |Total Norm: 2.9210e-03 |Residual: 1.0364e-03 |A: -2.7309e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.5651e-02 |Residual: 3.1249e-07 |A: 1.5651e-02| Relative Norm : 5.3581e+00
# Iteration: 2
# |Total Norm: 1.6492e-07 |Residual: 2.2828e-12 |A: 1.6492e-07| Relative Norm : 5.6461e-05
# Iteration: 3
# |Total Norm: 5.6961e-13 |Residual: 3.6543e-14 |A: 5.6843e-13| Relative Norm : 1.9501e-10
#
# Arc-Length Step 5 :
# Iteration: 0
# |Total Norm: 2.9090e-03 |Residual: 1.0481e-03 |A: -2.7136e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.7172e-02 |Residual: 3.2787e-07 |A: 1.7172e-02| Relative Norm : 5.9031e+00
# Iteration: 2
# |Total Norm: 1.9284e-07 |Residual: 2.5705e-12 |A: 1.9284e-07| Relative Norm : 6.6291e-05
# Iteration: 3
# |Total Norm: 2.3178e-13 |Residual: 4.4999e-14 |A: 2.2737e-13| Relative Norm : 7.9679e-11
#
# Arc-Length Step 6 :
# Iteration: 0
# |Total Norm: 2.8975e-03 |Residual: 1.0598e-03 |A: -2.6967e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.8861e-02 |Residual: 3.4635e-07 |A: 1.8861e-02| Relative Norm : 6.5093e+00
# Iteration: 2
# |Total Norm: 2.2800e-07 |Residual: 2.9485e-12 |A: 2.2800e-07| Relative Norm : 7.8689e-05
# Iteration: 3
# |Total Norm: 6.8498e-13 |Residual: 6.2502e-14 |A: 6.8212e-13| Relative Norm : 2.3640e-10
#
# Arc-Length Step 7 :
# Iteration: 0
# |Total Norm: 2.8866e-03 |Residual: 1.0717e-03 |A: -2.6803e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.0739e-02 |Residual: 3.6851e-07 |A: 2.0739e-02| Relative Norm : 7.1847e+00
# Iteration: 2
# |Total Norm: 2.7270e-07 |Residual: 3.4443e-12 |A: 2.7270e-07| Relative Norm : 9.4471e-05
# Iteration: 3
# |Total Norm: 4.5983e-13 |Residual: 6.8195e-14 |A: 4.5475e-13| Relative Norm : 1.5930e-10
#
# Arc-Length Step 8 :
# Iteration: 0
# |Total Norm: 2.8763e-03 |Residual: 1.0838e-03 |A: -2.6643e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.2836e-02 |Residual: 3.9530e-07 |A: 2.2836e-02| Relative Norm : 7.9392e+00
# Iteration: 2
# |Total Norm: 3.3011e-07 |Residual: 4.0923e-12 |A: 3.3011e-07| Relative Norm : 1.1477e-04
# Iteration: 3
# |Total Norm: 6.8569e-13 |Residual: 6.9826e-14 |A: 6.8212e-13| Relative Norm : 2.3839e-10
#
# Arc-Length Step 9 :
# Iteration: 0
# |Total Norm: 2.8668e-03 |Residual: 1.0964e-03 |A: -2.6488e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.5187e-02 |Residual: 4.2876e-07 |A: 2.5187e-02| Relative Norm : 8.7857e+00
# Iteration: 2
# |Total Norm: 4.0481e-07 |Residual: 4.9360e-12 |A: 4.0481e-07| Relative Norm : 1.4121e-04
# Iteration: 3
# |Total Norm: 1.0267e-12 |Residual: 8.4650e-14 |A: 1.0232e-12| Relative Norm : 3.5813e-10
#
# Arc-Length Step 10 :
# Iteration: 0
# |Total Norm: 2.8580e-03 |Residual: 1.1096e-03 |A: -2.6338e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.7843e-02 |Residual: 4.7409e-07 |A: 2.7843e-02| Relative Norm : 9.7420e+00
# Iteration: 2
# |Total Norm: 5.0358e-07 |Residual: 6.0396e-12 |A: 5.0358e-07| Relative Norm : 1.7620e-04
# Iteration: 3
# |Total Norm: 5.7538e-13 |Residual: 8.9150e-14 |A: 5.6843e-13| Relative Norm : 2.0132e-10
#
# Arc-Length Step 11 :
# Iteration: 0
# |Total Norm: 2.8501e-03 |Residual: 1.1236e-03 |A: -2.6193e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.0880e-02 |Residual: 5.4720e-07 |A: 3.0880e-02| Relative Norm : 1.0835e+01
# Iteration: 2
# |Total Norm: 6.3731e-07 |Residual: 7.4877e-12 |A: 6.3731e-07| Relative Norm : 2.2361e-04
# Iteration: 3
# |Total Norm: 1.5944e-12 |Residual: 9.3980e-14 |A: 1.5916e-12| Relative Norm : 5.5942e-10
#
# Arc-Length Step 12 :
# Iteration: 0
# |Total Norm: 2.8430e-03 |Residual: 1.1387e-03 |A: -2.6050e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.4426e-02 |Residual: 7.0134e-07 |A: 3.4426e-02| Relative Norm : 1.2109e+01
# Iteration: 2
# |Total Norm: 8.2567e-07 |Residual: 9.4231e-12 |A: 8.2567e-07| Relative Norm : 2.9042e-04
# Iteration: 3
# |Total Norm: 1.4836e-12 |Residual: 1.2957e-13 |A: 1.4779e-12| Relative Norm : 5.2184e-10
#
# Arc-Length Step 13 :
# Iteration: 0
# |Total Norm: 2.8368e-03 |Residual: 1.1553e-03 |A: -2.5909e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.8736e-02 |Residual: 1.1108e-06 |A: 3.8736e-02| Relative Norm : 1.3655e+01
# Iteration: 2
# |Total Norm: 1.1118e-06 |Residual: 1.2119e-11 |A: 1.1118e-06| Relative Norm : 3.9192e-04
# Iteration: 3
# |Total Norm: 2.0493e-12 |Residual: 1.1035e-13 |A: 2.0464e-12| Relative Norm : 7.2241e-10
#
# Arc-Length Step 14 :
# Iteration: 0
# |Total Norm: 2.8314e-03 |Residual: 1.1741e-03 |A: -2.5765e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 4.4413e-02 |Residual: 2.2979e-06 |A: 4.4413e-02| Relative Norm : 1.5686e+01
# Iteration: 2
# |Total Norm: 1.6211e-06 |Residual: 1.6402e-11 |A: 1.6211e-06| Relative Norm : 5.7253e-04
# Iteration: 3
# |Total Norm: 2.5054e-12 |Residual: 1.4717e-13 |A: 2.5011e-12| Relative Norm : 8.8487e-10
#
# Arc-Length Step 15 :
# Iteration: 0
# |Total Norm: 2.8268e-03 |Residual: 1.1963e-03 |A: -2.5612e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.3135e-02 |Residual: 5.8622e-06 |A: 5.3135e-02| Relative Norm : 1.8797e+01
# Iteration: 2
# |Total Norm: 2.8787e-06 |Residual: 2.9626e-11 |A: 2.8787e-06| Relative Norm : 1.0184e-03
# Iteration: 3
# |Total Norm: 5.9133e-12 |Residual: 1.3853e-13 |A: 5.9117e-12| Relative Norm : 2.0919e-09
#
# Arc-Length Step 16 :
# Iteration: 0
# |Total Norm: 2.8237e-03 |Residual: 1.2265e-03 |A: -2.5434e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 7.0013e-02 |Residual: 1.6860e-05 |A: 7.0013e-02| Relative Norm : 2.4794e+01
# Iteration: 2
# |Total Norm: 8.2940e-06 |Residual: 4.7981e-10 |A: 8.2940e-06| Relative Norm : 2.9373e-03
# Iteration: 3
# |Total Norm: 1.2460e-10 |Residual: 1.3293e-13 |A: 1.2460e-10| Relative Norm : 4.4126e-08
# Iteration: 4
# |Total Norm: 1.9470e-13 |Residual: 1.5806e-13 |A: -1.1369e-13| Relative Norm : 6.8951e-11
#
# Arc-Length Step 17 :
# Iteration: 0
# |Total Norm: 2.8294e-03 |Residual: 1.2857e-03 |A: -2.5204e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.0766e-01 |Residual: 4.5741e-05 |A: 1.0766e-01| Relative Norm : 3.8050e+01
# Iteration: 2
# |Total Norm: 5.3205e-05 |Residual: 1.5898e-08 |A: 5.3205e-05| Relative Norm : 1.8804e-02
# Iteration: 3
# |Total Norm: 3.9540e-09 |Residual: 8.0727e-13 |A: 3.9540e-09| Relative Norm : 1.3975e-06
# Iteration: 4
# |Total Norm: 2.8773e-13 |Residual: 1.7632e-13 |A: -2.2737e-13| Relative Norm : 1.0169e-10
#
# Arc-Length Step 18 :
# Iteration: 0
# |Total Norm: 2.8955e-03 |Residual: 1.4819e-03 |A: -2.4875e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.6342e-01 |Residual: 7.1521e-05 |A: 1.6342e-01| Relative Norm : 5.6438e+01
# Iteration: 2
# |Total Norm: 5.6206e-04 |Residual: 4.1324e-07 |A: 5.6206e-04| Relative Norm : 1.9412e-01
# Iteration: 3
# |Total Norm: 5.8920e-08 |Residual: 3.2143e-11 |A: 5.8920e-08| Relative Norm : 2.0349e-05
# Iteration: 4
# |Total Norm: 1.0359e-12 |Residual: 1.6213e-13 |A: 1.0232e-12| Relative Norm : 3.5778e-10
#
# Arc-Length Step 19 :
# Iteration: 0
# |Total Norm: 3.2065e-03 |Residual: 2.0757e-03 |A: -2.4440e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.7591e-01 |Residual: 3.2532e-05 |A: 1.7591e-01| Relative Norm : 5.4860e+01
# Iteration: 2
# |Total Norm: 1.5599e-03 |Residual: 1.2866e-06 |A: 1.5599e-03| Relative Norm : 4.8649e-01
# Iteration: 3
# |Total Norm: 1.4979e-10 |Residual: 1.8909e-11 |A: 1.4859e-10| Relative Norm : 4.6714e-08
# Iteration: 4
# |Total Norm: 4.3253e-12 |Residual: 2.1291e-13 |A: -4.3201e-12| Relative Norm : 1.3489e-09
#
# Arc-Length Step 20 :
# Iteration: 0
# |Total Norm: 3.6809e-03 |Residual: 2.7881e-03 |A: -2.4033e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.5892e-01 |Residual: 5.4124e-06 |A: 1.5892e-01| Relative Norm : 4.3174e+01
# Iteration: 2
# |Total Norm: 1.5820e-04 |Residual: 7.7125e-08 |A: 1.5820e-04| Relative Norm : 4.2980e-02
# Iteration: 3
# |Total Norm: 1.7453e-09 |Residual: 2.8052e-13 |A: -1.7453e-09| Relative Norm : 4.7416e-07
# Iteration: 4
# |Total Norm: 2.6619e-13 |Residual: 2.4069e-13 |A: 1.1369e-13| Relative Norm : 7.2317e-11
#
# Arc-Length Step 21 :
# Iteration: 0
# |Total Norm: 3.8044e-03 |Residual: 2.9703e-03 |A: -2.3772e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.4570e-01 |Residual: 7.1325e-06 |A: 1.4570e-01| Relative Norm : 3.8298e+01
# Iteration: 2
# |Total Norm: 1.4451e-04 |Residual: 1.1104e-07 |A: 1.4451e-04| Relative Norm : 3.7984e-02
# Iteration: 3
# |Total Norm: 3.4063e-09 |Residual: 5.8800e-13 |A: -3.4063e-09| Relative Norm : 8.9535e-07
# Iteration: 4
# |Total Norm: 2.4274e-13 |Residual: 2.1447e-13 |A: -1.1369e-13| Relative Norm : 6.3804e-11
#
# Arc-Length Step 22 :
# Iteration: 0
# |Total Norm: 3.6646e-03 |Residual: 2.8038e-03 |A: -2.3597e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.4433e-01 |Residual: 9.8690e-06 |A: 1.4433e-01| Relative Norm : 3.9385e+01
# Iteration: 2
# |Total Norm: 2.2029e-04 |Residual: 1.3885e-07 |A: 2.2029e-04| Relative Norm : 6.0114e-02
# Iteration: 3
# |Total Norm: 4.1707e-09 |Residual: 8.0165e-13 |A: -4.1707e-09| Relative Norm : 1.1381e-06
# Iteration: 4
# |Total Norm: 2.5307e-13 |Residual: 2.2610e-13 |A: 1.1369e-13| Relative Norm : 6.9058e-11
#
# Arc-Length Step 23 :
# Iteration: 0
# |Total Norm: 3.4945e-03 |Residual: 2.5934e-03 |A: -2.3422e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.5665e-01 |Residual: 9.0757e-06 |A: 1.5665e-01| Relative Norm : 4.4826e+01
# Iteration: 2
# |Total Norm: 1.4838e-04 |Residual: 7.7482e-08 |A: 1.4838e-04| Relative Norm : 4.2461e-02
# Iteration: 3
# |Total Norm: 2.5047e-09 |Residual: 3.3822e-13 |A: -2.5047e-09| Relative Norm : 7.1676e-07
# Iteration: 4
# |Total Norm: 2.2573e-13 |Residual: 1.9501e-13 |A: 1.1369e-13| Relative Norm : 6.4596e-11
#
# Arc-Length Step 24 :
# Iteration: 0
# |Total Norm: 3.3632e-03 |Residual: 2.4353e-03 |A: -2.3197e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.8279e-01 |Residual: 7.9173e-06 |A: 1.8279e-01| Relative Norm : 5.4349e+01
# Iteration: 2
# |Total Norm: 1.0408e-04 |Residual: 3.8906e-08 |A: 1.0408e-04| Relative Norm : 3.0946e-02
# Iteration: 3
# |Total Norm: 1.2441e-09 |Residual: 2.5822e-13 |A: -1.2441e-09| Relative Norm : 3.6990e-07
# Iteration: 4
# |Total Norm: 3.1451e-13 |Residual: 3.1451e-13 |A: 0.0000e+00| Relative Norm : 9.3514e-11
#
# Arc-Length Step 25 :
# Iteration: 0
# |Total Norm: 3.2737e-03 |Residual: 2.3414e-03 |A: -2.2880e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.2449e-01 |Residual: 7.5565e-06 |A: 2.2449e-01| Relative Norm : 6.8573e+01
# Iteration: 2
# |Total Norm: 1.0951e-04 |Residual: 2.1360e-08 |A: 1.0951e-04| Relative Norm : 3.3450e-02
# Iteration: 3
# |Total Norm: 5.4251e-10 |Residual: 2.0178e-13 |A: -5.4251e-10| Relative Norm : 1.6572e-07
# Iteration: 4
# |Total Norm: 2.7048e-13 |Residual: 2.4543e-13 |A: 1.1369e-13| Relative Norm : 8.2623e-11
#
# Arc-Length Step 26 :
# Iteration: 0
# |Total Norm: 3.2189e-03 |Residual: 2.3088e-03 |A: -2.2429e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.8462e-01 |Residual: 8.4481e-06 |A: 2.8462e-01| Relative Norm : 8.8421e+01
# Iteration: 2
# |Total Norm: 1.7149e-04 |Residual: 1.4864e-08 |A: 1.7149e-04| Relative Norm : 5.3278e-02
# Iteration: 3
# |Total Norm: 4.2407e-11 |Residual: 3.7075e-13 |A: -4.2405e-11| Relative Norm : 1.3174e-08
#
# Arc-Length Step 27 :
# Iteration: 0
# |Total Norm: 3.1969e-03 |Residual: 2.3394e-03 |A: -2.1788e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.6546e-01 |Residual: 1.0895e-05 |A: 3.6546e-01| Relative Norm : 1.1432e+02
# Iteration: 2
# |Total Norm: 3.2945e-04 |Residual: 1.7688e-08 |A: 3.2945e-04| Relative Norm : 1.0306e-01
# Iteration: 3
# |Total Norm: 6.4756e-10 |Residual: 3.0336e-13 |A: 6.4756e-10| Relative Norm : 2.0256e-07
# Iteration: 4
# |Total Norm: 3.2466e-13 |Residual: 3.0410e-13 |A: 1.1369e-13| Relative Norm : 1.0156e-10
#
# Arc-Length Step 28 :
# Iteration: 0
# |Total Norm: 3.2162e-03 |Residual: 2.4454e-03 |A: -2.0890e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 4.6647e-01 |Residual: 1.5343e-05 |A: 4.6647e-01| Relative Norm : 1.4504e+02
# Iteration: 2
# |Total Norm: 7.0392e-04 |Residual: 3.6333e-08 |A: 7.0392e-04| Relative Norm : 2.1887e-01
# Iteration: 3
# |Total Norm: 2.3234e-09 |Residual: 2.9693e-13 |A: 2.3234e-09| Relative Norm : 7.2241e-07
# Iteration: 4
# |Total Norm: 2.4597e-13 |Residual: 2.1812e-13 |A: 1.1369e-13| Relative Norm : 7.6478e-11
#
# Arc-Length Step 29 :
# Iteration: 0
# |Total Norm: 3.3019e-03 |Residual: 2.6528e-03 |A: -1.9660e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.8378e-01 |Residual: 2.2681e-05 |A: 5.8378e-01| Relative Norm : 1.7680e+02
# Iteration: 2
# |Total Norm: 1.6570e-03 |Residual: 9.0960e-08 |A: 1.6570e-03| Relative Norm : 5.0185e-01
# Iteration: 3
# |Total Norm: 8.0312e-09 |Residual: 2.7681e-13 |A: 8.0312e-09| Relative Norm : 2.4323e-06
# Iteration: 4
# |Total Norm: 3.1367e-13 |Residual: 2.9234e-13 |A: -1.1369e-13| Relative Norm : 9.4997e-11
#
# Arc-Length Step 30 :
# Iteration: 0
# |Total Norm: 3.5041e-03 |Residual: 3.0053e-03 |A: -1.8019e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 7.1767e-01 |Residual: 3.4084e-05 |A: 7.1767e-01| Relative Norm : 2.0481e+02
# Iteration: 2
# |Total Norm: 4.3923e-03 |Residual: 2.5053e-07 |A: 4.3923e-03| Relative Norm : 1.2535e+00
# Iteration: 3
# |Total Norm: 3.5645e-08 |Residual: 6.6941e-13 |A: 3.5645e-08| Relative Norm : 1.0173e-05
# Iteration: 4
# |Total Norm: 5.5727e-13 |Residual: 3.2211e-13 |A: 4.5475e-13| Relative Norm : 1.5903e-10
#
# Arc-Length Step 31 :
# Iteration: 0
# |Total Norm: 3.9084e-03 |Residual: 3.5699e-03 |A: -1.5909e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 8.8098e-01 |Residual: 4.7887e-05 |A: 8.8098e-01| Relative Norm : 2.2541e+02
# Iteration: 2
# |Total Norm: 1.2559e-02 |Residual: 7.3161e-07 |A: 1.2559e-02| Relative Norm : 3.2133e+00
# Iteration: 3
# |Total Norm: 1.9531e-07 |Residual: 4.5164e-12 |A: 1.9531e-07| Relative Norm : 4.9973e-05
# Iteration: 4
# |Total Norm: 1.3926e-12 |Residual: 2.7940e-13 |A: 1.3642e-12| Relative Norm : 3.5630e-10
#
# Arc-Length Step 32 :
# Iteration: 0
# |Total Norm: 4.6199e-03 |Residual: 4.4224e-03 |A: -1.3362e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.0243e+00 |Residual: 5.1899e-05 |A: 1.0243e+00| Relative Norm : 2.2171e+02
# Iteration: 2
# |Total Norm: 2.8171e-02 |Residual: 1.5934e-06 |A: 2.8171e-02| Relative Norm : 6.0978e+00
# Iteration: 3
# |Total Norm: 5.4003e-07 |Residual: 6.1793e-12 |A: 5.4003e-07| Relative Norm : 1.1689e-04
# Iteration: 4
# |Total Norm: 2.6319e-12 |Residual: 2.9984e-13 |A: 2.6148e-12| Relative Norm : 5.6970e-10
#
# Arc-Length Step 33 :
# Iteration: 0
# |Total Norm: 5.6038e-03 |Residual: 5.5012e-03 |A: -1.0677e-03| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 9.5287e-01 |Residual: 3.9237e-05 |A: 9.5287e-01| Relative Norm : 1.7004e+02
# Iteration: 2
# |Total Norm: 2.2671e-02 |Residual: 1.1405e-06 |A: 2.2671e-02| Relative Norm : 4.0456e+00
# Iteration: 3
# |Total Norm: 2.3351e-07 |Residual: 3.0472e-12 |A: 2.3351e-07| Relative Norm : 4.1670e-05
# Iteration: 4
# |Total Norm: 1.1069e-12 |Residual: 4.2224e-13 |A: -1.0232e-12| Relative Norm : 1.9752e-10
#
# Arc-Length Step 34 :
# Iteration: 0
# |Total Norm: 6.3787e-03 |Residual: 6.3216e-03 |A: -8.5147e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 7.3160e-01 |Residual: 3.4064e-05 |A: 7.3160e-01| Relative Norm : 1.1470e+02
# Iteration: 2
# |Total Norm: 5.0131e-04 |Residual: 5.2939e-08 |A: 5.0131e-04| Relative Norm : 7.8592e-02
# Iteration: 3
# |Total Norm: 2.0256e-09 |Residual: 4.1516e-13 |A: 2.0256e-09| Relative Norm : 3.1755e-07
# Iteration: 4
# |Total Norm: 3.3325e-13 |Residual: 3.1326e-13 |A: -1.1369e-13| Relative Norm : 5.2245e-11
#
# Arc-Length Step 35 :
# Iteration: 0
# |Total Norm: 6.4406e-03 |Residual: 6.3982e-03 |A: -7.3760e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.9353e-01 |Residual: 4.4245e-05 |A: 5.9353e-01| Relative Norm : 9.2155e+01
# Iteration: 2
# |Total Norm: 1.2605e-02 |Residual: 5.5588e-07 |A: 1.2605e-02| Relative Norm : 1.9571e+00
# Iteration: 3
# |Total Norm: 1.8251e-07 |Residual: 1.0904e-11 |A: 1.8251e-07| Relative Norm : 2.8338e-05
# Iteration: 4
# |Total Norm: 1.2245e-12 |Residual: 4.5500e-13 |A: -1.1369e-12| Relative Norm : 1.9013e-10
#
# Arc-Length Step 36 :
# Iteration: 0
# |Total Norm: 6.0150e-03 |Residual: 5.9728e-03 |A: -7.1083e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.2591e-01 |Residual: 4.5916e-05 |A: 5.2591e-01| Relative Norm : 8.7433e+01
# Iteration: 2
# |Total Norm: 2.0135e-02 |Residual: 6.6933e-07 |A: 2.0135e-02| Relative Norm : 3.3474e+00
# Iteration: 3
# |Total Norm: 3.8975e-07 |Residual: 1.5583e-11 |A: 3.8975e-07| Relative Norm : 6.4796e-05
# Iteration: 4
# |Total Norm: 2.0824e-12 |Residual: 3.8558e-13 |A: -2.0464e-12| Relative Norm : 3.4620e-10
#
# Arc-Length Step 37 :
# Iteration: 0
# |Total Norm: 5.5146e-03 |Residual: 5.4658e-03 |A: -7.3166e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.3205e-01 |Residual: 4.0958e-05 |A: 5.3205e-01| Relative Norm : 9.6481e+01
# Iteration: 2
# |Total Norm: 2.0439e-02 |Residual: 4.9309e-07 |A: 2.0439e-02| Relative Norm : 3.7064e+00
# Iteration: 3
# |Total Norm: 3.6020e-07 |Residual: 8.5452e-12 |A: 3.6020e-07| Relative Norm : 6.5317e-05
# Iteration: 4
# |Total Norm: 1.2867e-12 |Residual: 3.0266e-13 |A: -1.2506e-12| Relative Norm : 2.3332e-10
#
# Arc-Length Step 38 :
# Iteration: 0
# |Total Norm: 5.1015e-03 |Residual: 5.0426e-03 |A: -7.7338e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 7.6261e-01 |Residual: 3.8800e-05 |A: 7.6261e-01| Relative Norm : 1.4949e+02
# Iteration: 2
# |Total Norm: 3.0684e-02 |Residual: 6.1108e-07 |A: 3.0684e-02| Relative Norm : 6.0146e+00
# Iteration: 3
# |Total Norm: 9.4715e-07 |Residual: 1.4829e-11 |A: 9.4715e-07| Relative Norm : 1.8566e-04
# Iteration: 4
# |Total Norm: 6.5573e-13 |Residual: 3.2691e-13 |A: -5.6843e-13| Relative Norm : 1.2854e-10
#
# Arc-Length Step 39 :
# Iteration: 0
# |Total Norm: 4.8233e-03 |Residual: 4.7529e-03 |A: -8.2120e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.6963e+00 |Residual: 5.3253e-05 |A: 1.6963e+00| Relative Norm : 3.5168e+02
# Iteration: 2
# |Total Norm: 1.1965e-01 |Residual: 2.7513e-06 |A: 1.1965e-01| Relative Norm : 2.4806e+01
# Iteration: 3
# |Total Norm: 2.3882e-05 |Residual: 4.4528e-10 |A: 2.3882e-05| Relative Norm : 4.9513e-03
# Iteration: 4
# |Total Norm: 9.4433e-12 |Residual: 3.7076e-13 |A: 9.4360e-12| Relative Norm : 1.9578e-09
#
# Arc-Length Step 40 :
# Iteration: 0
# |Total Norm: 4.8098e-03 |Residual: 4.7321e-03 |A: -8.6129e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 5.5232e+00 |Residual: 1.4295e-04 |A: 5.5232e+00| Relative Norm : 1.1483e+03
# Iteration: 2
# |Total Norm: 2.0117e+00 |Residual: 5.2073e-05 |A: 2.0117e+00| Relative Norm : 4.1824e+02
# Iteration: 3
# |Total Norm: 1.3781e-02 |Residual: 2.6845e-07 |A: 1.3781e-02| Relative Norm : 2.8652e+00
# Iteration: 4
# |Total Norm: 3.0384e-06 |Residual: 7.6668e-11 |A: 3.0384e-06| Relative Norm : 6.3171e-04
# Iteration: 5
# |Total Norm: 2.9779e-12 |Residual: 3.6153e-13 |A: 2.9559e-12| Relative Norm : 6.1913e-10
#
# Arc-Length Step 41 :
# Iteration: 0
# |Total Norm: 6.4302e-03 |Residual: 6.3744e-03 |A: -8.4548e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 2.3783e+01 |Residual: 5.9491e-04 |A: 2.3783e+01| Relative Norm : 3.6986e+03
# Iteration: 2
# |Total Norm: 4.9767e+02 |Residual: 1.1819e-02 |A: 4.9767e+02| Relative Norm : 7.7396e+04
# Iteration: 3
# |Total Norm: 3.7820e+02 |Residual: 1.1236e-03 |A: 3.7820e+02| Relative Norm : 5.8816e+04
# Iteration: 4
# |Total Norm: 6.4922e+01 |Residual: 6.1393e-04 |A: 6.4922e+01| Relative Norm : 1.0096e+04
# Iteration: 5
# |Total Norm: 2.9324e+00 |Residual: 4.3942e-05 |A: 2.9324e+00| Relative Norm : 4.5604e+02
# Iteration: 6
# |Total Norm: 1.7244e-01 |Residual: 8.1956e-07 |A: 1.7244e-01| Relative Norm : 2.6816e+01
# Iteration: 7
# |Total Norm: 4.3222e-05 |Residual: 4.8280e-10 |A: 4.3222e-05| Relative Norm : 6.7217e-03
# Iteration: 8
# |Total Norm: 1.8559e-12 |Residual: 3.6816e-13 |A: 1.8190e-12| Relative Norm : 2.8862e-10
#
# Arc-Length Step 42 :
# Iteration: 0
# |Total Norm: 4.2592e-02 |Residual: 4.2592e-02 |A: -2.6150e-06| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 8.5733e+01 |Residual: 1.8075e-03 |A: 8.5733e+01| Relative Norm : 2.0129e+03
# Iteration: 2
# |Total Norm: 5.2524e+02 |Residual: 2.3050e-03 |A: 5.2524e+02| Relative Norm : 1.2332e+04
# Iteration: 3
# |Total Norm: 5.8941e+01 |Residual: 9.1477e-04 |A: 5.8941e+01| Relative Norm : 1.3839e+03
# Iteration: 4
# |Total Norm: 1.1782e+01 |Residual: 1.9353e-04 |A: 1.1782e+01| Relative Norm : 2.7663e+02
# Iteration: 5
# |Total Norm: 4.8992e-01 |Residual: 1.4188e-05 |A: 4.8992e-01| Relative Norm : 1.1503e+01
# Iteration: 6
# |Total Norm: 1.8758e-03 |Residual: 2.8770e-08 |A: 1.8758e-03| Relative Norm : 4.4041e-02
# Iteration: 7
# |Total Norm: 1.9494e-08 |Residual: 7.6627e-13 |A: 1.9494e-08| Relative Norm : 4.5770e-07
# Iteration: 8
# |Total Norm: 4.7642e-13 |Residual: 4.7642e-13 |A: 0.0000e+00| Relative Norm : 1.1186e-11
#
# Arc-Length Step 43 :
# Iteration: 0
# |Total Norm: 1.7091e-02 |Residual: 1.7087e-02 |A: 3.5695e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 6.5012e+00 |Residual: 3.2475e-04 |A: 6.5012e+00| Relative Norm : 3.8039e+02
# Iteration: 2
# |Total Norm: 1.9397e+01 |Residual: 6.1949e-04 |A: 1.9397e+01| Relative Norm : 1.1349e+03
# Iteration: 3
# |Total Norm: 1.9274e-01 |Residual: 1.0127e-06 |A: 1.9274e-01| Relative Norm : 1.1277e+01
# Iteration: 4
# |Total Norm: 1.8726e-04 |Residual: 2.2262e-09 |A: 1.8726e-04| Relative Norm : 1.0956e-02
# Iteration: 5
# |Total Norm: 2.7402e-11 |Residual: 4.0808e-13 |A: -2.7399e-11| Relative Norm : 1.6033e-09
#
# Arc-Length Step 44 :
# Iteration: 0
# |Total Norm: 2.4884e-02 |Residual: 2.4882e-02 |A: 2.6769e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.4474e+01 |Residual: 8.3556e-04 |A: 3.4474e+01| Relative Norm : 1.3854e+03
# Iteration: 2
# |Total Norm: 6.0001e+02 |Residual: 2.3537e-02 |A: 6.0001e+02| Relative Norm : 2.4113e+04
# Iteration: 3
# |Total Norm: 1.1431e+02 |Residual: 1.3991e-03 |A: 1.1431e+02| Relative Norm : 4.5936e+03
# Iteration: 4
# |Total Norm: 4.0535e+03 |Residual: 1.2417e-01 |A: 4.0535e+03| Relative Norm : 1.6290e+05
# Iteration: 5
# |Total Norm: 1.1009e+03 |Residual: 2.9108e-02 |A: 1.1009e+03| Relative Norm : 4.4242e+04
# Iteration: 6
# |Total Norm: 5.0670e+02 |Residual: 1.6506e-02 |A: 5.0670e+02| Relative Norm : 2.0363e+04
# Iteration: 7
# |Total Norm: 5.5929e+01 |Residual: 9.2975e-04 |A: 5.5929e+01| Relative Norm : 2.2476e+03
# Iteration: 8
# |Total Norm: 6.9026e+02 |Residual: 2.7591e-02 |A: 6.9026e+02| Relative Norm : 2.7739e+04
# Iteration: 9
# |Total Norm: 1.4931e+02 |Residual: 1.6825e-03 |A: 1.4931e+02| Relative Norm : 6.0002e+03
# Iteration: 10
# |Total Norm: 8.3992e+03 |Residual: 2.0240e-01 |A: 8.3992e+03| Relative Norm : 3.3754e+05
# Iteration: 11
# |Total Norm: 2.2593e+03 |Residual: 3.7766e-01 |A: 2.2593e+03| Relative Norm : 9.0794e+04
# Iteration: 12
# |Total Norm: 5.5173e+02 |Residual: 8.3644e-02 |A: 5.5173e+02| Relative Norm : 2.2172e+04
# Iteration: 13
# |Total Norm: 6.8491e+01 |Residual: 8.7709e-03 |A: 6.8491e+01| Relative Norm : 2.7524e+03
# Iteration: 14
# |Total Norm: 1.8127e+02 |Residual: 6.4664e-03 |A: 1.8127e+02| Relative Norm : 7.2848e+03
# Iteration: 15
# |Total Norm: 5.4892e+01 |Residual: 2.0542e-03 |A: 5.4892e+01| Relative Norm : 2.2059e+03
# Iteration: 16
# |Total Norm: 4.6070e+03 |Residual: 1.4889e-01 |A: 4.6070e+03| Relative Norm : 1.8514e+05
# Iteration: 17
# |Total Norm: 1.5795e+04 |Residual: 9.6293e-02 |A: 1.5795e+04| Relative Norm : 6.3475e+05
# Iteration: 18
# |Total Norm: 4.9339e+03 |Residual: 1.1649e-02 |A: 4.9339e+03| Relative Norm : 1.9828e+05
# Iteration: 19
# |Total Norm: 2.2792e+04 |Residual: 1.3140e-01 |A: 2.2792e+04| Relative Norm : 9.1595e+05
#
# Arc-Length Step 44 :
# Iteration: 0
# |Total Norm: 9.2836e-03 |Residual: 9.2836e-03 |A: 3.3510e-05| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.4605e+01 |Residual: 3.2691e-04 |A: 1.4605e+01| Relative Norm : 1.5732e+03
# Iteration: 2
# |Total Norm: 1.1928e+05 |Residual: 7.9113e+00 |A: 1.1928e+05| Relative Norm : 1.2849e+07
# Iteration: 3
# |Total Norm: 1.5155e+05 |Residual: 4.4117e+01 |A: 1.5155e+05| Relative Norm : 1.6325e+07
# Iteration: 4
# |Total Norm: 8.0663e+04 |Residual: 7.9570e+01 |A: 8.0662e+04| Relative Norm : 8.6887e+06
# Iteration: 5
# |Total Norm: 1.9229e+05 |Residual: 4.8261e+02 |A: 1.9229e+05| Relative Norm : 2.0713e+07
# Iteration: 6
# |Total Norm: 7.6955e+06 |Residual: 3.7439e+03 |A: 7.6955e+06| Relative Norm : 8.2893e+08
# Iteration: 7
# |Total Norm: 1.4735e+07 |Residual: 2.1822e+04 |A: 1.4735e+07| Relative Norm : 1.5872e+09
# Iteration: 8
# |Total Norm: 4.4457e+18 |Residual: 1.7451e+12 |A: 4.4457e+18| Relative Norm : 4.7887e+20
# Iteration: 9
# |Total Norm: 3.1833e+19 |Residual: 3.3643e+14 |A: 3.1833e+19| Relative Norm : 3.4289e+21
# Iteration: 10
# |Total Norm: 1.5021e+20 |Residual: 8.7484e+15 |A: 1.5021e+20| Relative Norm : 1.6180e+22
# Iteration: 11
# |Total Norm: 7.5038e+19 |Residual: 4.2284e+16 |A: 7.5038e+19| Relative Norm : 8.0828e+21
# Iteration: 12
# |Total Norm: 3.7265e+21 |Residual: 1.8956e+17 |A: 3.7265e+21| Relative Norm : 4.0140e+23
# Iteration: 13
# |Total Norm: 1.6718e+21 |Residual: 6.0915e+18 |A: 1.6718e+21| Relative Norm : 1.8008e+23
# Iteration: 14
# |Total Norm: 2.2303e+23 |Residual: 1.6798e+21 |A: 2.2302e+23| Relative Norm : 2.4024e+25
# Iteration: 15
# |Total Norm: 2.4158e+25 |Residual: 1.4201e+23 |A: 2.4158e+25| Relative Norm : 2.6022e+27
# Iteration: 16
# |Total Norm: 4.7389e+26 |Residual: 3.2529e+24 |A: 4.7388e+26| Relative Norm : 5.1046e+28
# Iteration: 17
# |Total Norm: 2.9528e+28 |Residual: 2.3331e+25 |A: 2.9528e+28| Relative Norm : 3.1807e+30
# Iteration: 18
# |Total Norm: 7.0442e+28 |Residual: 7.2192e+25 |A: 7.0442e+28| Relative Norm : 7.5878e+30
# Iteration: 19
# |Total Norm: 1.6785e+29 |Residual: 7.2355e+26 |A: 1.6785e+29| Relative Norm : 1.8081e+31
#
# Arc-Length Step 44 :
# Iteration: 0
# |Total Norm: 1.7306e-03 |Residual: 1.7306e-03 |A: 5.2417e-07| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 4.7744e+02 |Residual: 1.1642e-02 |A: 4.7744e+02| Relative Norm : 2.7588e+05
# Iteration: 2
# |Total Norm: 2.5100e+02 |Residual: 9.0976e-04 |A: 2.5100e+02| Relative Norm : 1.4503e+05
# Iteration: 3
# |Total Norm: 1.4919e+02 |Residual: 4.7019e-03 |A: 1.4919e+02| Relative Norm : 8.6209e+04
# Iteration: 4
# |Total Norm: 3.6840e+01 |Residual: 2.4376e-04 |A: 3.6840e+01| Relative Norm : 2.1287e+04
# Iteration: 5
# |Total Norm: 2.0450e+01 |Residual: 7.3264e-05 |A: 2.0450e+01| Relative Norm : 1.1816e+04
# Iteration: 6
# |Total Norm: 3.9688e+00 |Residual: 1.7251e-04 |A: 3.9688e+00| Relative Norm : 2.2933e+03
# Iteration: 7
# |Total Norm: 2.9063e-01 |Residual: 9.3490e-06 |A: 2.9063e-01| Relative Norm : 1.6793e+02
# Iteration: 8
# |Total Norm: 4.8906e-03 |Residual: 4.5643e-08 |A: 4.8906e-03| Relative Norm : 2.8259e+00
# Iteration: 9
# |Total Norm: 5.8190e-07 |Residual: 2.3685e-11 |A: 5.8190e-07| Relative Norm : 3.3624e-04
# Iteration: 10
# |Total Norm: 3.6802e-13 |Residual: 3.6801e-13 |A: 3.5527e-15| Relative Norm : 2.1266e-10
#
# Arc-Length Step 45 :
# Iteration: 0
# |Total Norm: 8.6544e-04 |Residual: 8.6544e-04 |A: 1.7609e-08| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 3.5353e+00 |Residual: 1.8981e-05 |A: 3.5353e+00| Relative Norm : 4.0850e+03
# Iteration: 2
# |Total Norm: 3.4943e-01 |Residual: 6.3068e-06 |A: 3.4943e-01| Relative Norm : 4.0375e+02
# Iteration: 3
# |Total Norm: 2.8586e-03 |Residual: 1.3324e-07 |A: 2.8586e-03| Relative Norm : 3.3031e+00
# Iteration: 4
# |Total Norm: 3.0169e-07 |Residual: 1.1405e-11 |A: 3.0169e-07| Relative Norm : 3.4860e-04
# Iteration: 5
# |Total Norm: 3.3286e-13 |Residual: 3.3281e-13 |A: 5.3291e-15| Relative Norm : 3.8461e-10
#
# Arc-Length Step 46 :
# Iteration: 0
# |Total Norm: 2.8663e-03 |Residual: 2.8663e-03 |A: -4.3800e-08| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 1.3785e+01 |Residual: 6.6517e-05 |A: 1.3785e+01| Relative Norm : 4.8095e+03
# Iteration: 2
# |Total Norm: 8.7225e-01 |Residual: 3.3346e-05 |A: 8.7225e-01| Relative Norm : 3.0431e+02
# Iteration: 3
# |Total Norm: 5.1668e-03 |Residual: 2.3176e-07 |A: 5.1668e-03| Relative Norm : 1.8026e+00
# Iteration: 4
# |Total Norm: 1.3848e-06 |Residual: 5.6482e-11 |A: 1.3848e-06| Relative Norm : 4.8313e-04
# Iteration: 5
# |Total Norm: 3.7398e-13 |Residual: 3.7337e-13 |A: -2.1316e-14| Relative Norm : 1.3047e-10
#
# Arc-Length Step 47 :
# Iteration: 0
# |Total Norm: 7.4433e-03 |Residual: 7.4432e-03 |A: -2.5353e-05| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 8.8200e+00 |Residual: 1.8965e-04 |A: 8.8200e+00| Relative Norm : 1.1850e+03
# Iteration: 2
# |Total Norm: 4.6960e+00 |Residual: 2.3002e-04 |A: 4.6960e+00| Relative Norm : 6.3091e+02
# Iteration: 3
# |Total Norm: 6.2828e-02 |Residual: 3.1794e-06 |A: 6.2828e-02| Relative Norm : 8.4409e+00
# Iteration: 4
# |Total Norm: 2.1259e-04 |Residual: 1.2377e-08 |A: 2.1259e-04| Relative Norm : 2.8562e-02
# Iteration: 5
# |Total Norm: 3.6127e-10 |Residual: 4.3240e-13 |A: 3.6127e-10| Relative Norm : 4.8536e-08
# Iteration: 6
# |Total Norm: 4.5498e-13 |Residual: 4.4055e-13 |A: -1.1369e-13| Relative Norm : 6.1126e-11
#
# Arc-Length Step 48 :
# Iteration: 0
# |Total Norm: 1.1778e-02 |Residual: 1.1766e-02 |A: -5.3169e-04| Relative Norm : 1.0000e+00
# Iteration: 1
# |Total Norm: 7.1028e+00 |Residual: 3.0700e-04 |A: 7.1028e+00| Relative Norm : 6.0308e+02
# Iteration: 2
# |Total Norm: 6.1495e+00 |Residual: 3.8218e-04 |A: 6.1495e+00| Relative Norm : 5.2214e+02

# %% [markdown]
# ## Post Processing
# Here we plot the final deformed shape and the equilibrium path.

# %%
# Get dof coordinates:
x_dofs = V.sub(0).sub(0).dofmap().dofs()
y_dofs = V.sub(0).sub(1).dofmap().dofs()
theta_dofs = V.sub(1).dofmap().dofs()
dofs = V.tabulate_dof_coordinates()
dof_coords = dofs.reshape((-1, 2))

# %%
x_nodal_coord = dof_coords[x_dofs][:,0]
y_nodal_coord = dof_coords[y_dofs][:,1]
# Get nodal values 

# Plot displacement field
disp_x = x_nodal_coord + disp[-1][x_dofs]
disp_y = y_nodal_coord + disp[-1][y_dofs]

plt.figure(figsize=(7,7))
plt.scatter(disp_x, disp_y, marker = '.', c = 'r', label = 'Deformed Configuration')
plt.scatter(x_nodal_coord,y_nodal_coord, marker = '.', c = 'k', alpha = 0.3, label = 'Initial Configuration')

plt.xlabel('x-coordinates')
plt.ylabel('y-coordinates')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.plot(-np.array(lmbda), f_reac, c='k', marker = 'o')
plt.xlabel('Applied Displacement')
plt.ylabel('Force')
plt.title('Equilibrium path')

# %% [markdown]
# ## Optional: Creating an animation from solution snapshots

# %%
from matplotlib import animation, rc

plt.rcParams["animation.html"] = "jshtml"

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)

ax.set_xlim([0,w])
ax.set_ylim([-10,H+10])

deformed, = ax.plot([], [], lw = 7, c = 'r', label = 'Deformed Configuration', ls = 'None', marker = '.')
init, = ax.plot(x_nodal_coord, y_nodal_coord, c='k', lw = 5, ls = 'None', label = 'Initial Configuration', marker = '.', alpha = 0.3)
ax.legend(loc = 'lower right')

def drawframe(n):
    disp_x = x_nodal_coord + disp[n][x_dofs]
    disp_y = y_nodal_coord + disp[n][y_dofs]
    
    deformed.set_data(disp_x,disp_y)
    return deformed,

plt.close()
# blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, drawframe, frames=len(lmbda), interval=40, blit=True)

anim
